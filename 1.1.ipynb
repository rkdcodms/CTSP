# %% [markdown]
# 1.1 2D coordinate frames
# P =(x,y)

# %%
import matplotlib.pyplot as plt

# 점의 좌표
p = (3, 5)

# 그래프 그리기
plt.figure(figsize=(6,6))
plt.plot(p[0], p[1], 'ro')  # 'ro'는 빨간색 점(red dot)
plt.text(p[0]+0.2, p[1], f'p{p}', fontsize=12)  # 점 옆에 좌표 표시

# 좌표축 범위 설정
plt.xlim(0, 10)
plt.ylim(0, 10)

# 격자와 축 추가
plt.grid(True)
plt.axhline(0, color='black', linewidth=0.5)
plt.axvline(0, color='black', linewidth=0.5)

plt.title("2D cooordinate frame")
plt.xlabel("x")
plt.ylabel("y")

plt.show()
